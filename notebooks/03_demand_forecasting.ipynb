# %% [markdown]
# # 03_demand_forecasting
# ## 1. 데이터 로드 및 Train/Test Split

# %%
import sys
from pathlib import Path

# notebooks/ 의 부모 폴더를 path에 추가
project_root = Path().resolve().parent  # notebooks/ 의 상위 폴더
sys.path.append(str(project_root / "src"))

from feature import preprocess
from model import train_model

# CSV 파일 경로
processed_csv = Path().resolve().parent / "data" / "processed" / "processed_data.csv"

# 모델 학습 실행
train_model(processed_csv)
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001330 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 6091
# [LightGBM] [Info] Number of data points in the train set: 13948, number of used features: 34
# [LightGBM] [Info] Start training from score 1570.087044
# [100]	valid_0's l1: 643.804	valid_0's l2: 724584
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [200]	valid_0's l1: 531.594	valid_0's l2: 490653
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %% [markdown]
# ## 2. 모델 학습
# - LightGBMRegressor 사용
# - eval_metric: l1
# - Feature importance 확인

# %% [markdown]
# ## 3. 결과 분석
# - Direction Accuracy
# - Big Error Detection
# - Top Features 시각화
# - forecast_error_predictions.csv 저장
