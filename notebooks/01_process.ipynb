# %% [markdown]
# # 01_process
# ## 1. CSV 불러오기 및 병합
# - Actual consumption, Forecasted consumption
# - Actual generation, Cross-border flows
# - Day-ahead prices, Weather data

# %%
import sys
from pathlib import Path

# notebooks/ 의 부모 폴더를 path에 추가
sys.path.append(str(Path().resolve().parent))

from src.feature import preprocess

# 실행
preprocess()
# Out:
# /Users/hyunkyung/Desktop/Projects/EuropeEnergyTradingAnalysis/src/feature.py:119: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[numeric_cols] = df[numeric_cols].fillna(method="bfill")
# ✅ Preprocessed data saved: /Users/hyunkyung/Desktop/Projects/EuropeEnergyTradingAnalysis/data/processed/processed_data.csv
#                  datetime  actual_load  forecast_load  wind_generation  solar  \
# 168   2024-01-08 00:00:00     53736.25       43782.25         20991.25   3.00
# 169   2024-01-08 01:00:00     52394.00       42136.50         21607.00   3.00
# 170   2024-01-08 02:00:00     52115.50       41322.25         22431.75   2.75
# 171   2024-01-08 03:00:00     52623.00       41524.25         22849.00   3.00
# 172   2024-01-08 04:00:00     52869.00       43910.50         22250.75   3.00
# ...                   ...          ...            ...              ...    ...
# ...

# %% [markdown]
# ## 2. 전처리 결과
# - Forecast error 계산
# - Lag, rolling, 파생 feature 생성
# - 최종 processed_data.csv 저장
