# %% [markdown]
# # 04_price_correlation
# ## 1. 데이터 로드

# %%
import sys
from pathlib import Path

# notebooks/ 의 부모 폴더를 path에 추가
project_root = Path().resolve().parent  # notebooks/ 의 상위 폴더
sys.path.append(str(project_root / "src"))

from evaluation import analyze_from_csv
from pathlib import Path

processed_csv = Path().resolve().parent / "data" / "processed" / "processed_data.csv"
result_csv = Path().resolve().parent / "data" / "processed" / "forecast_error_price_analysis.csv"

analyze_from_csv(csv_path=processed_csv, result_path=result_csv)
# Out:
# Forecast error spike rate: 8.57%
# Price spike rate: 2.95%
# Error spike leading to price spike: 0.27%
# ✅ Analysis CSV saved: /Users/hyunkyung/Desktop/Projects/EuropeEnergyTradingAnalysis/data/processed/forecast_error_price_analysis.csv

# %% [markdown]
# ## 2. Spike 정의
# - forecast error spike: ±2 std
# - price spike: ±2 std

# %% [markdown]
# ## 3. Spike 상관관계 분석
# - Crosstab, Heatmap
# - 가격 spike로 이어지는 오차 비율

# %% [markdown]
# ## 4. Alpha signal 생성
# - forecast_error spike 기반
# - 방향성 활용

# %% [markdown]
# ## 5. 시각화 및 CSV 저장
# - forecast_error_price_analysis.csv
